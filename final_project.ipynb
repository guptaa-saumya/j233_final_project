# %% [markdown]
# ### 1. Importing

# %%
import pandas as pd
import altair as alt

# %%
xls = pd.ExcelFile('residential-nonresidential-fire-loss-estimates-2003-2021_fixed.xlsx')
prop_type_totals = pd.read_excel(xls, 'Res Bldg Prop Typ Est 2003-2021')
fire_causes = pd.read_excel(xls, 'Res Bldg Fire Est by Cause')
death_by_cause = pd.read_excel(xls, 'Res Bld Fire Death Est by Cause')
injury_by_cause = pd.read_excel(xls, 'Res Bld Fire Inj Est by Cause')
cost_by_cause = pd.read_excel(xls, 'Res Bld Fire Dollr Est by Cause')

# %%
prop_type_totals.head()
# Out:
#    Years  Overall Res Building Fires  1 & 2 Family Fires  Multifamily Fires
# 0   2003                      381200              249400             108800  \
# 1   2004                      389800              254600             111700
# 2   2005                      376500              245900             107000
# 3   2006                      392700              253800             113900
# 4   2007                      390300              260700             104600
#
#    Overall Deaths  1 & 2 Family Deaths  Multifamily Deaths  Overall Injuries
# 0            3000                 2480                 380             13425  \
# 1            3050                 2485                 425             13650
# 2            2895                 2225                 510             13375
# 3            2490                 1925                 445             12550
# 4            2765                 2285                 405             13525
#
#    1 & 2 Family Injuries  Multifamily Injuries  Overall Dollars Los
# 0                   9200                  3650           8376800000  \
# 1                   9275                  3775           8097100000
# 2                   8950                  3800           9013900000
# 3                   8225                  3725           8932300000
# 4                   9125                  3875           9353500000
#
#    1 & 2 Family Dollars Loss  Multifamily Dollars Loss
# 0                 6603600000                1362200000
# 1                 6227800000                1509500000
# 2                 6929100000                1654400000
# 3                 6960600000                1570900000
# 4                 7520600000                1445700000

# %%
fire_causes.head()
# Out:
#    Years  Overall Intentional  1 & 2 Fam Intentional  Multi Fam Intentional
# 0   2003                17400                  17400                   3200  \
# 1   2004                17500                  17500                   3000
# 2   2005                18000                  18000                   3300
# 3   2006                18100                  18100                   3200
# 4   2007                19000                  19000                   3400
#
#    Overall Playing with Heat Source  1 &2 Fam Playing with Heat Source
# 0                              3500                               2800  \
# 1                              3100                               2400
# 2                              2900                               2300
# 3                              3200                               2500
# 4                              3100                               2400
#
#    Multi Fam Playing with Heat Source  Overall Smoking  1 & 2 Fam Smoking
# 0                                 700             8900               5600  \
# 1                                 600             9000               5600
# 2                                 600             8700               5400
# 3                                 700             9700               6000
# 4                                 600             8900               5700
#
#    Mulit Fam Smoking  ...  Overall Equipment Malfunction
# 0               2700  ...                          16100  \
# 1               2800  ...                          16000
# 2               2600  ...                          15100
# 3               3100  ...                          14700
# 4               2700  ...                          15200
#
#    1 & 2 Fam Equipment Malfunction  Multi Fam Equipment Malfunction
# 0                            12200                             3300  \
# 1                            12000                             3300
# 2                            11100                             3400
# 3                            10800                             3400
# 4                            11400                             3100
#
#    Overall Other Unintentional, Careless
# 0                                  22000  \
# 1                                  22300
# 2                                  22500
# 3                                  23400
# 4                                  25400
#
#    1 & 2 Fam Other Unintentional, Careless
# 0                                    17100  \
# 1                                    17400
# 2                                    17300
# 3                                    18200
# 4                                    20200
#
#    Multi Fam Other Unintentional, Careless  Overall Cause Under Investigation
# 0                                     4000                               2200  \
# 1                                     4000                               2400
# 2                                     4100                               2900
# 3                                     4100                               3300
# 4                                     4000                               3800
#
#    1 & 2 Fam Cause Under Investigation  Multi Fam Cause Under Investigation
# 0                                 1800                                  400  \
# 1                                 1900                                  400
# 2                                 2200                                  500
# 3                                 2500                                  600
# 4                                 2900                                  700
#
#    Total Residential*
# 0              381200
# 1              389800
# 2              376500
# 3              392700
# 4              390300
#
# [5 rows x 47 columns]

# %%
death_by_cause.head()
# Out:
#    Years  Overall Intentional  1 & 2 Fam Intentional  Multi Fam Intentional
# 0   2003                  265                    220                     40  \
# 1   2004                  255                    220                     35
# 2   2005                  350                    280                     55
# 3   2006                  250                    175                     50
# 4   2007                  310                    265                     35
#
#    Overall Playing with Heat Source  1 &2 Fam Playing with Heat Source
# 0                               130                                130  \
# 1                                60                                 45
# 2                                55                                 30
# 3                                80                                 75
# 4                                55                                 50
#
#   Multi Fam Playing with Heat Source  Overall Smoking  1 & 2 Fam Smoking
# 0                                 <3              500                320  \
# 1                                  5              505                380
# 2                                 20              510                350
# 3                                 10              485                360
# 4                                 <3              470                340
#
#    Mulit Fam Smoking  ...  Multi Fam Exposure  Overall Equipment Malfunction
# 0                120  ...                  <3                            100  \
# 1                 95  ...                  <3                            155
# 2                120  ...                  15                            120
# 3                 90  ...                  10                             90
# 4                100  ...                  <3                            120
#
#    1 & 2 Fam Equipment Malfunction  Multi Fam Equipment Malfunction
# 0                               95                                5  \
# 1                              105                               25
# 2                               90                               30
# 3                               65                               20
# 4                              115                                5
#
#    Overall Other Unintentional, Careless
# 0                                    440  \
# 1                                    430
# 2                                    410
# 3                                    365
# 4                                    380
#
#    1 & 2 Fam Other Unintentional, Careless
# 0                                      365  \
# 1                                      350
# 2                                      370
# 3                                      310
# 4                                      325
#
#    Multi Fam Other Unintentional, Careless  Overall Cause Under Investigation
# 0                                       55                                215  \
# 1                                       60                                195
# 2                                       30                                205
# 3                                       35                                165
# 4                                       50                                240
#
#    1 & 2 Fam Cause Under Investigation  Multi Fam Cause Under Investigation
# 0                                  205                                    5
# 1                                  170                                   25
# 2                                  160                                   40
# 3                                  120                                   35
# 4                                  205                                   35
#
# [5 rows x 46 columns]

# %%
injury_by_cause
