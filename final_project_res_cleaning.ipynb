# %% [markdown]
# I. Importing

# %%
import pandas as pd
import altair as alt

# %%
cause_of_fire = pd.read_csv('resbuildingfires_cause.csv')
death_causes = pd.read_csv('resbuildingfires_death_causes.csv')
types_of_res = pd.read_csv('resbuildingfires_estimate_types.csv')
dollar_loss = pd.read_csv('resbuildingfires_dollars.csv')

# %%
cause_of_fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Years                          19 non-null     float64
#  1   Intentional                    19 non-null     object
#  2   Playing with Heat Source       19 non-null     object
#  3   Smoking                        19 non-null     object
#  4   Heating                        19 non-null     object
#  5   Cooking                        19 non-null     object
#  6   Electrical Malfunction         19 non-null     object
#  7   Appliances                     19 non-null     object
#  8   Open Flame                     19 non-null     object
#  9   Other Heat                     19 non-null     object
#  10  Other Equipment                19 non-null     object
#  11  Natural                        19 non-null     object
# ...

# %%
cause_of_fire['Years'] = pd.to_datetime(cause_of_fire['Years'], format='%Y') 
# cause_of_fire['Intentional'] = cause_of_fire['Intentional'].astype(str).astype(int)
# cause_of_fire[
#     'Intentional', 'Playing with Heat Source', 'Smoking', 'Heating', 'Cooking', 'Electrical Malfunction', 'Appliances', 
#     'Open Flame', 'Other Heat', 'Other Equipment', 'Natural', 'Exposure', 'Equipment Malfunction', 'Other Uninentional, Careless',
#     'Cause Under Investigation', 'Total Residential'] = pd.to_numeric(cause_of_fire[
#     'Intentional', 'Playing with Heat Source', 'Smoking', 'Heating', 'Cooking', 'Electrical Malfunction', 'Appliances', 
#     'Open Flame', 'Other Heat', 'Other Equipment', 'Natural', 'Exposure', 'Equipment Malfunction', 'Other Uninentional, Careless',
#     'Cause Under Investigation', 'Total Residential'])

# %%
cause_of_fire.head()
# Out:
#        Years Intentional Playing with Heat Source Smoking Heating   Cooking
# 0 2003-01-01      17,400                    3,500   8,900   61,100  153,000  \
# 1 2004-01-01      17,500                    3,100   9,000   60,600  162,900
# 2 2005-01-01      18,000                    2,900   8,700   54,200  155,500
# 3 2006-01-01      18,100                    3,200   9,700   53,600  168,400
# 4 2007-01-01      19,000                    3,100   8,900   54,400  161,700
#
#   Electrical Malfunction Appliances  Open Flame  Other Heat Other Equipment
# 0                 26,400       9,200      23,700     17,900           6,000  \
# 1                 27,000       8,600      23,100     17,800           5,600
# 2                 28,500       8,500      22,900     17,600           5,000
# 3                 30,000       9,700      22,300     16,100           5,000
# 4                 30,600      10,200      20,900     15,400           4,600
#
# ...

# %%
death_causes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Years                          19 non-null     timedelta64[ns]
#  1   Intentional                    19 non-null     float64
#  2   Playing with Heat Source       19 non-null     float64
#  3   Smoking                        19 non-null     float64
#  4   Heating                        19 non-null     float64
#  5   Cooking                        19 non-null     float64
#  6   Electrical Malfunction         19 non-null     float64
#  7   Appliances                     19 non-null     float64
#  8   Open Flame                     19 non-null     float64
#  9   Other Heat                     19 non-null     float64
#  10  Other Equipment                19 non-null     float64
#  11  Natural                        19 non-null     float64
# ...

# %%
death_causes.head()
# Out:
#        Years  Intentional  Playing with Heat Source  Smoking  Heating
# 0 2003-01-01        265.0                     130.0    500.0     155.0  \
# 1 2004-01-01        255.0                      60.0    505.0     200.0
# 2 2005-01-01        350.0                      55.0    510.0     220.0
# 3 2006-01-01        250.0                      80.0    485.0     175.0
# 4 2007-01-01        310.0                      55.0    470.0     175.0
#
#    Cooking  Electrical Malfunction  Appliances   Open Flame   Other Heat
# 0    110.0                   360.0         80.0        310.0       195.0  \
# 1    200.0                   350.0         80.0        295.0       220.0
# 2    135.0                   310.0         30.0        240.0       220.0
# 3    120.0                   290.0         15.0        205.0       185.0
# 4    105.0                   295.0         35.0        245.0       240.0
#
#    Other Equipment  Natural Exposure  Equipment Malfunction
# ...

# %%
types_of_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Years              19 non-null     timedelta64[ns]
#  1   1 & 2 Family       19 non-null     object
#  2   Multifamily        19 non-null     object
#  3   Other              19 non-null     object
#  4   Total Residential  19 non-null     object
# dtypes: object(4), timedelta64[ns](1)
# memory usage: 3.5+ KB

# %%
types_of_res['Years'] = pd.to_datetime(types_of_res['Years'], format='%Y')

# %%
types_of_res.head()
# Out:
#        Years 1 & 2 Family  Multifamily   Other Total Residential
# 0 2003-01-01       249,400     108,800  23,000           381,200
# 1 2004-01-01       254,600     111,700  23,500           389,800
# 2 2005-01-01       245,900     107,000  23,700           376,500
# 3 2006-01-01       253,800     113,900  25,000           392,700
# 4 2007-01-01       260,700     104,600  25,000           390,300

# %%
types_of_res['Multifamily'] = types_of_res['Multifamily'].astype(str).astype(int)
types_of_res['1 & 2 Family'] = types_of_res['1 & 2 Family'].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 types_of_res['Multifamily'] = types_of_res['Multifamily'].astype(str).astype(int)
#       2 types_of_res['1 & 2 Family'] = types_of_res['1 & 2 Family'].astype(str).astype(int)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...

# %%
dollar_loss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Years                          19 non-null     float64
#  1   Intentional                    19 non-null     object
#  2   Playing with Heat Source       19 non-null     object
#  3   Smoking                        19 non-null     object
#  4   Heating                        19 non-null     object
#  5   Cooking                        19 non-null     object
#  6   Electrical Malfunction         19 non-null     object
#  7   Appliances                     19 non-null     object
#  8   Open Flame                     19 non-null     object
#  9   Other Heat                     19 non-null     object
#  10  Other Equipment                19 non-null     object
#  11  Natural                        19 non-null     object
# ...

# %%
dollar_loss['Years'] = pd.to_datetime(dollar_loss['Years'], format='%Y')

# %%
dollar_loss.head()
# Out:
#        Years  Intentional Playing with Heat Source      Smoking     Heating
# 0 2003-01-01  761,200,000              180,200,000  363,700,000  497,700,000  \
# 1 2004-01-01  716,600,000              154,600,000  375,800,000  414,100,000
# 2 2005-01-01  784,600,000              175,700,000  423,600,000  409,800,000
# 3 2006-01-01  719,900,000              152,300,000  434,000,000  421,400,000
# 4 2007-01-01  630,800,000              121,900,000  345,800,000  338,800,000
#
#        Cooking Electrical Malfunction  Appliances     Open Flame
# 0  379,300,000          1,295,000,000  328,100,000    982,000,000  \
# 1  320,600,000          1,296,700,000  265,600,000  1,016,900,000
# 2  370,700,000          1,564,700,000  283,900,000  1,135,100,000
# 3  324,400,000          1,371,200,000  313,700,000    964,800,000
# 4  299,100,000          1,326,600,000  259,400,000    862,000,000
#
#       Other Heat Other Equipment      Natural       Exposure
# ...

# %%
types_of_res['1 & 2 Family'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1 & 2 Family'
#
# ...
